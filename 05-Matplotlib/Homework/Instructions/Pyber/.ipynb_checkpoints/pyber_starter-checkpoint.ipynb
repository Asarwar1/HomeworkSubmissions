# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# %%
# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
city_data.head()

ride_data = pd.read_csv(ride_data_to_load)
ride_data.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Combine the data into a single dataset
combined_data = pd.merge(ride_data, city_data, how='outer', on='city')
len(combined_data)
combined_data.count()
# Out:
# city            2375
# date            2375
# fare            2375
# ride_id         2375
# driver_count    2375
# type            2375
# dtype: int64

# %%
# Display the data table for preview
combined_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
combined_data["counter"]= 1 # create a ride counter

city_unique = combined_data.drop_duplicates('city') # Drop duplicates by city
city_unique.dtypes
city_drivers=city_unique.set_index('city',inplace=True)


urban = combined_data.loc[(combined_data["type"] == "Urban")]
suburban = combined_data.loc[(combined_data["type"] == "Suburban")]
rural = combined_data.loc[(combined_data["type"] == "Rural")]

city_urban = urban.groupby('city')
city_suburban = suburban.groupby('city')
city_rural = rural.groupby('city')


rides_urban = city_urban["counter"].sum()
avgfare_urban = city_urban["fare"].mean()

rides_suburban = city_suburban["counter"].sum()
avgfare_suburban = city_suburban["fare"].mean()

rides_rural = city_rural["counter"].sum()
avgfare_rural = city_rural["fare"].mean()

# %%
# Build the scatter plots for each city types
fig, ax = plt.subplots()

plt.scatter(rides_urban, avgfare_urban, marker="o", facecolors="coral", edgecolors="black", 
            s=city_unique["driver_count"], alpha=0.7, label="Urban")
plt.scatter(rides_suburban, avgfare_suburban, marker="o", facecolors="lightblue", edgecolors="black", 
            s=city_unique["driver_count"], alpha=0.7, label="Suburban")
plt.scatter(rides_rural, avgfare_rural, marker="o", facecolors="yellow", edgecolors="black", 
            s=city_unique["driver_count"], alpha=0.7, label="Rural")

# %%
# Incorporate the other graph properties
plt.xlim(0, 41)
plt.ylim(19, 45)
ax.grid(linestyle='-', linewidth='0.5',)
plt.title('Pyber Ride Sharing Data (2016)')

plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')
# Out:
# Text(0, 0.5, 'Average Fare ($)')

# %%
# Create a legend
plt.legend(loc="best", fancybox=True, title="City Types")
# Out:
# No handles with labels found to put in legend.

# %%
# Incorporate a text label regarding circle size
plt.text(42,35, 'Note:\nCircle size correlates with driver count per City')
# Out:
# Text(42, 35, 'Note:\nCircle size correlates with driver count per City')

# %%
# Save Figure
plt.savefig('PyberScatterPlot.png')

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
group_type = combined_data.groupby('type')
group_type.head()

fares_tot=combined_data["fare"].sum()
fares_type = 100*(group_type["fare"].sum()/fares_tot)
fares_type

values = fares_type.values.tolist()
labels = fares_type.index.tolist()
labels
colors = ['gold','lightskyblue','lightcoral']
explode = (0 , 0 , 0.1)

# %%
# Build Pie Chart
plt.figure(figsize=(6,3))
plt.pie(values, labels=labels, colors=colors, startangle=150,  autopct='%.1f%%', explode=explode, shadow=True)
plt.axis('auto')
# plt.axis('equal')
plt.tight_layout()
plt.title('% of Total Fares by City Type')
# Out:
# Text(0.5, 1.0, '% of Total Fares by City Type')

# %%
# Save Figure
plt.savefig('PyberPieFares.png')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
rides_tot=combined_data["counter"].sum()
rides_type = 100*(group_type["counter"].sum()/rides_tot)
rides_type
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: counter, dtype: float64

# %%
# Build Pie Chart
values_f = rides_type.values.tolist()
labels_f = rides_type.index.tolist()


plt.figure(figsize=(6,3))
plt.pie(values_f, labels=labels_f, colors=colors, startangle=150,  autopct='%.1f%%', explode=explode, shadow=True)
plt.axis('auto')
plt.tight_layout()
plt.title('% of Total Rides by City Type')
# Out:
# Text(0.5, 1.0, '% of Total Rides by City Type')

# %%
# Save Figure
plt.savefig('PyberPieRides.png')

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
group_drivers = combined_data.drop_duplicates('city') # Drop duplicates by city

drivers_tot=group_drivers["driver_count"].sum() # add up all drivers in the dataset
group_drivers = group_drivers.groupby('type') # group data by city type
drivers_type=group_drivers["driver_count"].sum() # add up drivers by city type
drivers_type = 100*(group_drivers["driver_count"].sum()/drivers_tot) # calculate total drivers by city type
drivers_type
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: counter, dtype: float64

# %%
# Build Pie Charts
values_d = drivers_type.values.tolist()
labels_d = drivers_type.index.tolist()

plt.figure(figsize=(6,3))
plt.pie(values_d, labels=labels_d, colors=colors, startangle=150,  autopct='%.1f%%', explode=explode, shadow=True)
plt.axis('auto')
plt.tight_layout()
plt.title('% of Total Drivers by City Type')
# Out:
# Text(0.5, 1.0, '% of Total Rides by City Type')

# %%
# Save Figure
plt.savefig('PyberPieDrivers.png')

# %%
# Show Figure
plt.show()
